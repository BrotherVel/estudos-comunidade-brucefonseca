# %% [markdown]
# #### Classe - Programação orientada a Objetos

# %%
from MinhasClasses import Carro

# %%
carro1 = Carro('Fusca', 'VW', 'Azul', '1973')
carro2 = Carro('Uno', 'Fiat', 'Branco', '1986')

# %%
carro1.get_info_carro()
# Out:
# False

# %%
carro1.set_ligado(True)
carro1.get_info_carro()
# Out:
# True
