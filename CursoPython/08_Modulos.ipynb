# %% [markdown]
# ## Módulos

# %%
import meuModulo as mb

# %%
mb.Servico_Manutencao()
# Out:
# Lista de Serviços de Manutenção:
# 1 - Troca de Óleo
# 2 - Filtro de Ar
# 3 - Pastilhas de Freio
# 4 - Bateria
# 5 - Alinhamento
# Deseja contratar algum serviço? (s/n)
# s
# Foi adicionado o serviço 'Bateria' ao carrinho
# Deseja adicionar mais algum serviço? (s/n)
# Então vamos continuar para a próxima etápa !!
#
# Consulte a tabela com o valor e o tempo de manutenção totais:
#
# Índice     | Item                 | Preço         | Tempo
# ----------------------------------------------------------------------
# 1          | Bateria              | R$ 100        | 60 min
# ----------------------------------------------------------------------
#            | Total                | R$ 100        | 1h
